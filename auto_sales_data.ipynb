# %%
#AUTO SALES ANALYSIS

# %%
#import pandas, matplotlib, numpy, seaborn

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
#shows folder python is searching file from

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HP

# %%
#reading the file

# %%
df = pd.read_csv("Auto Sales data.csv")

# %%
#Showing the folder Python is searching file from
import os
print(os.getcwd())
# Out:
# C:\Users\HP

# %%
#changing directorate, for python to search folder from below path
os.chdir(r"C:\Users\HP\Documents")

# %%
#confirming whether directorate has been changed
print(os.getcwd())
# Out:
# C:\Users\HP\Documents

# %%
#load file
df = pd.read_csv("Auto Sales data.csv")

# %%
#check var type
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
#check 1st few rows
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1    7/5/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2    1/7/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
df.shape
# Out:
# (2747, 20)

# %%
#define column names
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
print("Shape (rows, columns):", df.shape, "\n")
# Out:
# Shape (rows, columns): (2747, 20)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %%
#defines total rows, non-null and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
#defines total null values
df.isnull().sum()
# Out:
# ORDERNUMBER             0
# QUANTITYORDERED         0
# PRICEEACH               0
# ORDERLINENUMBER         0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# PRODUCTCODE             0
# CUSTOMERNAME            0
# PHONE                   0
# ADDRESSLINE1            0
# CITY                    0
# POSTALCODE              0
# COUNTRY                 0
# CONTACTLASTNAME         0
# CONTACTFIRSTNAME        0
# DEALSIZE                0
# dtype: int64

# %%
#replace missing with 0
df.fillna(0, inplace=True)

# %%
#drop rows with missing values
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1    7/5/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2    1/7/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
#add total sales column & sum total sales
df['TOTAL_SALES'] = df['QUANTITYORDERED'] * df['PRICEEACH']
df['TOTAL_SALES'].sum()
# Out:
# 9760221.770000001

# %%
df['TOTAL_SALES'].mean()
# Out:
# 3553.047604659629

# %%
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum()
# Out:
# PRODUCTLINE
# Classic Cars        3842868.52
# Motorcycles         1103512.19
# Planes               969323.50
# Ships                700039.22
# Trains               226243.47
# Trucks and Buses    1111559.19
# Vintage Cars        1806675.68
# Name: TOTAL_SALES, dtype: float64

# %%
df.groupby('COUNTRY')['TOTAL_SALES'].sum()
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.56
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3355575.71
# Name: TOTAL_SALES, dtype: float64

# %%
#best selling Productline
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().idxmax()
# Out:
# 'Classic Cars'

# %%
#Country with highest sales
df.groupby('COUNTRY')['TOTAL_SALES'].sum().idxmax()
# Out:
# 'USA'

# %%
#country with lowest sales
df.groupby('COUNTRY')['TOTAL_SALES'].sum().idxmin()
# Out:
# 'Ireland'

# %%
#lowest selling productline
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().idxmin()
# Out:
# 'Trains'

# %%
#sorting productline from best
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().sort_values(ascending=False)
# Out:
# PRODUCTLINE
# Classic Cars        3842868.52
# Vintage Cars        1806675.68
# Trucks and Buses    1111559.19
# Motorcycles         1103512.19
# Planes               969323.50
# Ships                700039.22
# Trains               226243.47
# Name: TOTAL_SALES, dtype: float64

# %%
#sorting countries from best performing
df.groupby('COUNTRY')['TOTAL_SALES'].sum().sort_values(ascending=False)
# Out:
# COUNTRY
# USA            3355575.71
# Spain          1215686.92
# France         1110916.56
# Australia       630623.10
# UK              478880.46
# Italy           374674.31
# Finland         329581.91
# Norway          307463.70
# Singapore       288488.41
# Denmark         245637.15
# Canada          224078.56
# Germany         220472.09
# Sweden          210014.21
# Austria         202062.53
# Japan           188167.81
# Switzerland     117713.56
# Belgium         108412.62
# Philippines      94015.73
# Ireland          57756.43
# Name: TOTAL_SALES, dtype: float64

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP  ...  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95  ...
# 1    7/5/2018                   757  Shipped  Motorcycles    95  ...
# 2    1/7/2018                   703  Shipped  Motorcycles    95  ...
# 3  25/08/2018                   649  Shipped  Motorcycles    95  ...
# 4  28/10/2018                   586  Shipped  Motorcycles    95  ...
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
df.groupby('DEALSIZE')['TOTAL_SALES'].sum().sort_values(ascending=False)
# Out:
# DEALSIZE
# Medium    5931231.47
# Small     2570033.84
# Large     1258956.46
# Name: TOTAL_SALES, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().plot(kind='bar')
plt.title("Sales by Productline")
plt.show()

# %%
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Sales by Productline")
plt.show()

# %%
df.groupby('PRODUCTLINE')['TOTAL_SALES'].sum().plot(kind='bar')
plt.title("Sales By Productline")
plt.show()

# %%
df.groupby('COUNTRY')['TOTAL_SALES'].sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Sales by Country")
plt.show()

# %% [markdown]
# #***Sales by Country***

# %%
if 'COUNTRY' in df.columns:
    country_sales = df.groupby('COUNTRY')['TOTAL_SALES'].sum().sort_values(ascending=False)

    plt.figure(figsize=(8,5))
    sns.barplot(x=region_sales.index, y=country_sales.values, palette="viridis")
    plt.title("Sales by Country")
    plt.xlabel("Country")
    plt.ylabel("Total Sales")
    plt.show()

    print("Best Performing Country:", region_sales.idxmax(), "with sales of", country_sales.max(), "\n")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9320\3634930335.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=region_sales.index, y=country_sales.values, palette="viridis")
# Best Performing Country: USA with sales of 3355575.71

# %%
df.groupby("PRODUCTLINE")["TOTAL_SALES"].sum().plot(kind="pie", autopct="%1.1f%%")
plt.ylabel("")
plt.title("Sales by Productline")
plt.show()

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

df = pd.read_csv("Auto Sales data.csv")

st.title("🚗 Auto Sales Dashboard")
# Out:
# DeltaGenerator()
